# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import os
os.name
# Out:
# 'nt'

# %%
if os.name=='posix':
    sns.set(font='AppleGothic')
elif os.name=='nt':
    sns.set(font='Malgun Gothic')

# %%
pd.read_csv('kb.csv',encoding = "cp949")
# Out:
#     국가(대륙)별          상품군별   판매유형별 2014 1/4 2014 2/4 2014 3/4 2014 4/4  \
# 0        합계            합계       계   148272   153641   163999   213216
# 1        합계            합계     면세점        -        -        -        -
# 2        합계            합계  면세점 이외        -        -        -        -
# 3        합계    컴퓨터 및 주변기기       계     4915     4052     3912     3529
# 4        합계    컴퓨터 및 주변기기     면세점        -        -        -        -
# ..      ...           ...     ...      ...      ...      ...      ...
# 445      기타  생활용품 및 자동차용품     면세점        -        -        -        -
# 446      기타  생활용품 및 자동차용품  면세점 이외        -        -        -        -
# 447      기타           기 타       계      765      735      849      804
# 448      기타           기 타     면세점        -        -        -        -
# 449      기타           기 타  면세점 이외        -        -        -        -
#
#     2015 1/4 2015 2/4 2015 3/4  ... 2017 3/4 2017 4/4 2018 1/4 2018 2/4  \
# 0     269101   271784   268421  ...   749612   858240   828752   893026
# 1          -        -        -  ...   610630   677884   665613   725319
# 2          -        -        -  ...   138982   180356   163139   167707
# 3       2903     2697     3804  ...     2018     2158     2042     1485
# 4          -        -        -  ...        5        1        2        6
# ..       ...      ...      ...  ...      ...      ...      ...      ...
# 445        -        -        -  ...        0        0        0        0
# 446        -        -        -  ...      567      634      665      469
# 447      788      805      724  ...      814     1101     1067     1063
# 448        -        -        -  ...       82      266      272      316
# 449        -        -        -  ...      732      835      795      747
#
#     2018 3/4  2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4 p)
# 0     917330    964762   1244311   1338103   1517805      1860640
# 1     761836    766783   1070693   1157158   1336372      1645003
# 2     155494    197979    173618    180945    181433       215637
# 3       1554      1791      1656      1530      1438         1571
# 4          1         0         2         0         1           70
# ..       ...       ...       ...       ...       ...          ...
# 445        0         0         0         0         0            0
# 446      504       589       465       488       308          531
# 447     1120       770       711       689       469         1094
# 448      404         0         0         1         0            1
# 449      716       770       711       688       469         1093
#
# [450 rows x 27 columns]

# %%
df_raw=pd.read_csv('kb.csv',encoding = "cp949")
df_raw.shape
# Out:
# (450, 27)

# %%
df_raw=df_raw[df_raw['국가(대륙)별']=='미국']

# %%
df_raw
# Out:
#    국가(대륙)별          상품군별   판매유형별 2014 1/4 2014 2/4 2014 3/4 2014 4/4 2015 1/4  \
# 45      미국            합계       계    25773    22573    21288    26729    39945
# 46      미국            합계     면세점        -        -        -        -        -
# 47      미국            합계  면세점 이외        -        -        -        -        -
# 48      미국    컴퓨터 및 주변기기       계     2216     1666     1776     1675     1469
# 49      미국    컴퓨터 및 주변기기     면세점        -        -        -        -        -
# 50      미국    컴퓨터 및 주변기기  면세점 이외        -        -        -        -        -
# 51      미국    가전·전자·통신기기       계     2875     2758     2894     3527     4397
# 52      미국    가전·전자·통신기기     면세점        -        -        -        -        -
# 53      미국    가전·전자·통신기기  면세점 이외        -        -        -        -        -
# 54      미국         소프트웨어       계       47       57       49      128      182
# 55      미국         소프트웨어     면세점        -        -        -        -        -
# 56      미국         소프트웨어  면세점 이외        -        -        -        -        -
# 57      미국           서 적       계      962      720      934     1006     1074
# 58      미국           서 적     면세점        -        -        -        -        -
# 59      미국           서 적  면세점 이외        -        -        -        -        -
# 60      미국         사무·문구       계       25       10       14       18      568
# 61      미국         사무·문구     면세점        -        -        -        -        -
# 62      미국         사무·문구  면세점 이외        -        -        -        -        -
# 63      미국     음반·비디오·악기       계      787      720      722      821      849
# 64      미국     음반·비디오·악기     면세점        -        -        -        -        -
# 65      미국     음반·비디오·악기  면세점 이외        -        -        -        -        -
# 66      미국  의류 및 패션관련 상품       계     9810     7801     6404     9208     8602
# 67      미국  의류 및 패션관련 상품     면세점        -        -        -        -        -
# 68      미국  의류 및 패션관련 상품  면세점 이외        -        -        -        -        -
# 69      미국      스포츠·레저용품       계      573      539      475      491      541
# 70      미국      스포츠·레저용품     면세점        -        -        -        -        -
# 71      미국      스포츠·레저용품  면세점 이외        -        -        -        -        -
# 72      미국           화장품       계     3740     3713     3399     4595    11223
# 73      미국           화장품     면세점        -        -        -        -        -
# 74      미국           화장품  면세점 이외        -        -        -        -        -
# 75      미국       아동·유아용품       계      583      546      499      610     1099
# 76      미국       아동·유아용품     면세점        -        -        -        -        -
# 77      미국       아동·유아용품  면세점 이외        -        -        -        -        -
# 78      미국         음·식료품       계      381      415      405      673      577
# 79      미국         음·식료품     면세점        -        -        -        -        -
# 80      미국         음·식료품  면세점 이외        -        -        -        -        -
# 81      미국         농축수산물       계       94       98      111      160      189
# 82      미국         농축수산물     면세점        -        -        -        -        -
# 83      미국         농축수산물  면세점 이외        -        -        -        -        -
# 84      미국  생활용품 및 자동차용품       계     1931     1915     1815     1871     6605
# 85      미국  생활용품 및 자동차용품     면세점        -        -        -        -        -
# 86      미국  생활용품 및 자동차용품  면세점 이외        -        -        -        -        -
# 87      미국           기 타       계     1749     1615     1791     1946     2570
# 88      미국           기 타     면세점        -        -        -        -        -
# 89      미국           기 타  면세점 이외        -        -        -        -        -
#
#    2015 2/4 2015 3/4  ... 2017 3/4 2017 4/4 2018 1/4 2018 2/4 2018 3/4  \
# 45    26654    28647  ...    41927    53209    41204    39108    36536
# 46        -        -  ...     9469    12177     5184     3603     2317
# 47        -        -  ...    32458    41032    36020    35505    34219
# 48     1393     2166  ...      791      854      696      567      773
# 49        -        -  ...        0        0        0        0        0
# 50        -        -  ...      791      854      696      567      773
# 51     3589     2982  ...     2575     2394     1737     1716     1723
# 52        -        -  ...       29       32       65       38       72
# 53        -        -  ...     2546     2362     1672     1678     1651
# 54      113      163  ...       37      125      175      251      172
# 55        -        -  ...        0        0        0        0        0
# 56        -        -  ...       37      125      175      251      172
# 57      837      993  ...     1876     1856     2089     1790     2033
# 58        -        -  ...        0        0        0        0        0
# 59        -        -  ...     1876     1856     2089     1790     2033
# 60       17       32  ...       30       79       58       55       85
# 61        -        -  ...        0        0        0        0        0
# 62        -        -  ...       30       79       58       55       85
# 63      781      827  ...     2281     2647     2362     3014     3932
# 64        -        -  ...        0        0        0        0        0
# 65        -        -  ...     2281     2647     2362     3014     3932
# 66     6927     8055  ...    11173    14483    11761    12125    10224
# 67        -        -  ...      148      129      116      154      134
# 68        -        -  ...    11025    14354    11645    11971    10090
# 69      527      481  ...      874     1121     1110     1389     1142
# 70        -        -  ...        0        0        0        0        1
# 71        -        -  ...      874     1121     1110     1389     1141
# 72     6176     7061  ...    15997    22310    13896    11200     9700
# 73        -        -  ...     9202    11913     4927     3311     2028
# 74        -        -  ...     6795    10397     8969     7889     7672
# 75      603      619  ...      592      722      766      793      730
# 76        -        -  ...        1        0        1        0        2
# 77        -        -  ...      591      722      765      793      728
# 78      628      631  ...      417      265      277      311      239
# 79        -        -  ...       89      103       75      100       80
# 80        -        -  ...      328      162      202      211      159
# 81      192      193  ...        0        2        1        0        0
# 82        -        -  ...        0        0        0        0        0
# 83        -        -  ...        0        2        1        0        0
# 84     2189     2207  ...     2349     2276     2483     2357     2150
# 85        -        -  ...        0        0        0        0        0
# 86        -        -  ...     2349     2276     2483     2357     2150
# 87     2682     2237  ...     2935     4075     3793     3540     3633
# 88        -        -  ...        0        0        0        0        0
# 89        -        -  ...     2935     4075     3793     3540     3633
#
#     2018 4/4  2019 1/4  2019 2/4  2019 3/4  2019 4/4 p)
# 45     47981     39995     43443     53852        51478
# 46      2071      2657      2951      1818         1483
# 47     45910     37338     40492     52034        49995
# 48       854       621       646       934          802
# 49         0         0         0         0            0
# 50       854       621       646       934          802
# 51      1886      1845      1837      3166         1778
# 52        52        66       116       107           49
# 53      1834      1779      1721      3059         1729
# 54       269        88       156       118          338
# 55         0         0         0         0            0
# 56       269        88       156       118          338
# 57      1977      2259      1564      2550         1720
# 58         0         0         0         0            0
# 59      1977      2259      1564      2550         1720
# 60        83       198        72        81          101
# 61         0         0         0         0            0
# 62        83       198        72        81          101
# 63      4550      3857      5191      5757         4786
# 64         0         0         0         0            0
# 65      4550      3857      5191      5757         4786
# 66     13664     12079     12990     12903        15352
# 67       116       110       115        95           92
# 68     13548     11969     12875     12808        15260
# 69      1010      1107      1549      3074          802
# 70         0         4         0         0            0
# 71      1010      1103      1549      3074          802
# 72     15719     10794     11286     13658        12379
# 73      1780      2366      2647      1550         1272
# 74     13939      8428      8639     12108        11107
# 75      1056       815      1153      1698         1928
# 76         0         0         0         0            0
# 77      1056       815      1153      1698         1928
# 78       276       336       313       601          424
# 79       123       111        73        64           70
# 80       153       225       240       537          354
# 81        33         2         2         7            2
# 82         0         0         0         0            0
# 83        33         2         2         7            2
# 84      2159      2174      2411      3408         3713
# 85         0         0         0         2            0
# 86      2159      2174      2411      3406         3713
# 87      4445      3820      4273      5897         7353
# 88         0         0         0         0            0
# 89      4445      3820      4273      5897         7353
#
# [45 rows x 27 columns]

# %%
df_raw.melt?

# %%
df_raw.melt(id_vars=['국가(대륙)별','상품군별','판매유형별'])
# Out:
#      국가(대륙)별          상품군별   판매유형별     variable  value
# 0         미국            합계       계     2014 1/4  25773
# 1         미국            합계     면세점     2014 1/4      -
# 2         미국            합계  면세점 이외     2014 1/4      -
# 3         미국    컴퓨터 및 주변기기       계     2014 1/4   2216
# 4         미국    컴퓨터 및 주변기기     면세점     2014 1/4      -
# ...      ...           ...     ...          ...    ...
# 1075      미국  생활용품 및 자동차용품     면세점  2019 4/4 p)      0
# 1076      미국  생활용품 및 자동차용품  면세점 이외  2019 4/4 p)   3713
# 1077      미국           기 타       계  2019 4/4 p)   7353
# 1078      미국           기 타     면세점  2019 4/4 p)      0
# 1079      미국           기 타  면세점 이외  2019 4/4 p)   7353
#
# [1080 rows x 5 columns]

# %%
df=df_raw.melt(id_vars=['국가(대륙)별','상품군별','판매유형별'],var_name='기간',value_name='백만원')
df.shape
# Out:
# (1080, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  1080 non-null   object
#  1   상품군별     1080 non-null   object
#  2   판매유형별    1080 non-null   object
#  3   기간       1080 non-null   object
#  4   백만원      1080 non-null   object
# dtypes: object(5)
# memory usage: 42.3+ KB

# %%
df['기간']
# Out:
# 0          2014 1/4
# 1          2014 1/4
# 2          2014 1/4
# 3          2014 1/4
# 4          2014 1/4
#            ...
# 1075    2019 4/4 p)
# 1076    2019 4/4 p)
# 1077    2019 4/4 p)
# 1078    2019 4/4 p)
# 1079    2019 4/4 p)
# Name: 기간, Length: 1080, dtype: object

# %%
'2019 4/4 p'.split()
# Out:
# ['2019', '4/4', 'p']

# %%
'2019 4/4 p'.split()[0]
# Out:
# '2019'

# %%
type('2019 4/4 p'.split()[0])
# Out:
# str

# %%
int('2019 4/4 p'.split()[0])
# Out:
# 2019

# %%
df['기간'].map
# Out:
# <bound method Series.map of 0          2014 1/4
# 1          2014 1/4
# 2          2014 1/4
# 3          2014 1/4
# 4          2014 1/4
#            ...
# 1075    2019 4/4 p)
# 1076    2019 4/4 p)
# 1077    2019 4/4 p)
# 1078    2019 4/4 p)
# 1079    2019 4/4 p)
# Name: 기간, Length: 1080, dtype: object>

# %%
df['연도']=df['기간'].map(lambda x: int(x.split()[0]))

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간    백만원    연도
# 0      미국          합계       계  2014 1/4  25773  2014
# 1      미국          합계     면세점  2014 1/4      -  2014
# 2      미국          합계  면세점 이외  2014 1/4      -  2014
# 3      미국  컴퓨터 및 주변기기       계  2014 1/4   2216  2014
# 4      미국  컴퓨터 및 주변기기     면세점  2014 1/4      -  2014

# %%
'2019 4/4 p'.split()[1]
# Out:
# '4/4'

# %%
'2019 4/4 p'.split()[1].split('/')
# Out:
# ['4', '4']

# %%
'2019 4/4 p'.split()[1].split('/')[0]
# Out:
# '4'

# %%
df['분기']=df['기간'].map(lambda x: int(x.split()[1].split('/')[0]))

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간    백만원    연도  분기
# 0      미국          합계       계  2014 1/4  25773  2014   1
# 1      미국          합계     면세점  2014 1/4      -  2014   1
# 2      미국          합계  면세점 이외  2014 1/4      -  2014   1
# 3      미국  컴퓨터 및 주변기기       계  2014 1/4   2216  2014   1
# 4      미국  컴퓨터 및 주변기기     면세점  2014 1/4      -  2014   1

# %%
df['백만원']=df['백만원'].replace('-',pd.np.nan).astype(float)
df['백만원']
# Out:
# C:\Users\Public\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   """Entry point for launching an IPython kernel.
# 0       25773.0
# 1           NaN
# 2           NaN
# 3        2216.0
# 4           NaN
#          ...
# 1075        0.0
# 1076     3713.0
# 1077     7353.0
# 1078        0.0
# 1079     7353.0
# Name: 백만원, Length: 1080, dtype: float64

# %%
df.head()
# Out:
#   국가(대륙)별        상품군별   판매유형별        기간      백만원    연도  분기
# 0      미국          합계       계  2014 1/4  25773.0  2014   1
# 1      미국          합계     면세점  2014 1/4      NaN  2014   1
# 2      미국          합계  면세점 이외  2014 1/4      NaN  2014   1
# 3      미국  컴퓨터 및 주변기기       계  2014 1/4   2216.0  2014   1
# 4      미국  컴퓨터 및 주변기기     면세점  2014 1/4      NaN  2014   1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1080 entries, 0 to 1079
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  1080 non-null   object
#  1   상품군별     1080 non-null   object
#  2   판매유형별    1080 non-null   object
#  3   기간       1080 non-null   object
#  4   백만원      720 non-null    float64
#  5   연도       1080 non-null   int64
#  6   분기       1080 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 59.2+ KB

# %%
df=df[(df['국가(대륙)별']!='합계')&(df['상품군별']!='합계')].copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1008 entries, 3 to 1079
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   국가(대륙)별  1008 non-null   object
#  1   상품군별     1008 non-null   object
#  2   판매유형별    1008 non-null   object
#  3   기간       1008 non-null   object
#  4   백만원      672 non-null    float64
#  5   연도       1008 non-null   int64
#  6   분기       1008 non-null   int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 63.0+ KB

# %%
df.isna().sum()
# Out:
# 국가(대륙)별      0
# 상품군별         0
# 판매유형별        0
# 기간           0
# 백만원        336
# 연도           0
# 분기           0
# dtype: int64

# %%
df_total=df[df['판매유형별']=='계'].copy()
df_total.head()
# Out:
#    국가(대륙)별        상품군별 판매유형별        기간     백만원    연도  분기
# 3       미국  컴퓨터 및 주변기기     계  2014 1/4  2216.0  2014   1
# 6       미국  가전·전자·통신기기     계  2014 1/4  2875.0  2014   1
# 9       미국       소프트웨어     계  2014 1/4    47.0  2014   1
# 12      미국         서 적     계  2014 1/4   962.0  2014   1
# 15      미국       사무·문구     계  2014 1/4    25.0  2014   1

# %%
sns.lineplot(data=df_total,x='연도',y='백만원')

# %%
sns.lineplot(data=df_total,x='연도',y='백만원',hue='상품군별')
plt.legend(bbox_to_anchor=(1.05,1),loc=2,borderaxespad=0.)

# %%
sns.relplot(data=df_total, x="연도", y="백만원", hue="상품군별", kind="line")

# %%
sns.relplot(data=df_total,x='연도',y='백만원',hue='상품군별',kind='line',col='상품군별',col_wrap=4)

# %%
df_sub=df_total[~df_total['상품군별'].isin(['화장품'])].copy()

# %%
df_sub
# Out:
#      국가(대륙)별          상품군별 판매유형별           기간     백만원    연도  분기
# 3         미국    컴퓨터 및 주변기기     계     2014 1/4  2216.0  2014   1
# 6         미국    가전·전자·통신기기     계     2014 1/4  2875.0  2014   1
# 9         미국         소프트웨어     계     2014 1/4    47.0  2014   1
# 12        미국           서 적     계     2014 1/4   962.0  2014   1
# 15        미국         사무·문구     계     2014 1/4    25.0  2014   1
# ...      ...           ...   ...          ...     ...   ...  ..
# 1065      미국       아동·유아용품     계  2019 4/4 p)  1928.0  2019   4
# 1068      미국         음·식료품     계  2019 4/4 p)   424.0  2019   4
# 1071      미국         농축수산물     계  2019 4/4 p)     2.0  2019   4
# 1074      미국  생활용품 및 자동차용품     계  2019 4/4 p)  3713.0  2019   4
# 1077      미국           기 타     계  2019 4/4 p)  7353.0  2019   4
#
# [312 rows x 7 columns]

# %%
sns.relplot(data=df_sub,x='연도',y='백만원',hue='상품군별',col='상품군별',col_wrap=4,kind='line')

# %%
df_sub=df_total[~df_total['상품군별'].isin(['화장품','의류 및 패션관련 상품'])].copy()

# %%
df_sub
# Out:
#      국가(대륙)별          상품군별 판매유형별           기간     백만원    연도  분기
# 3         미국    컴퓨터 및 주변기기     계     2014 1/4  2216.0  2014   1
# 6         미국    가전·전자·통신기기     계     2014 1/4  2875.0  2014   1
# 9         미국         소프트웨어     계     2014 1/4    47.0  2014   1
# 12        미국           서 적     계     2014 1/4   962.0  2014   1
# 15        미국         사무·문구     계     2014 1/4    25.0  2014   1
# ...      ...           ...   ...          ...     ...   ...  ..
# 1065      미국       아동·유아용품     계  2019 4/4 p)  1928.0  2019   4
# 1068      미국         음·식료품     계  2019 4/4 p)   424.0  2019   4
# 1071      미국         농축수산물     계  2019 4/4 p)     2.0  2019   4
# 1074      미국  생활용품 및 자동차용품     계  2019 4/4 p)  3713.0  2019   4
# 1077      미국           기 타     계  2019 4/4 p)  7353.0  2019   4
#
# [288 rows x 7 columns]

# %%
sns.relplot(data=df_sub,x='연도',y='백만원',hue='상품군별',col='상품군별',col_wrap=4,kind='line')

# %%
df_cosmetic=df[df['상품군별']=='화장품'].copy()

# %%
df_cosmetic['상품군별'].unique()
# Out:
# array(['화장품'], dtype=object)

# %%
sns.lineplot(data=df_cosmetic, x='연도',y='백만원')

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df_cosmetic, x='연도',y='백만원',hue='분기')

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_cosmetic, x='기간',y='백만원')

# %%
df_cosmetic.head()
# Out:
#    국가(대륙)별 상품군별   판매유형별        기간     백만원    연도  분기
# 27      미국  화장품       계  2014 1/4  3740.0  2014   1
# 28      미국  화장품     면세점  2014 1/4     NaN  2014   1
# 29      미국  화장품  면세점 이외  2014 1/4     NaN  2014   1
# 72      미국  화장품       계  2014 2/4  3713.0  2014   2
# 73      미국  화장품     면세점  2014 2/4     NaN  2014   2

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
df_sub = df[df["판매유형별"] != "계"].copy()
sns.lineplot(data=df_sub, x="기간", y="백만원", hue="판매유형별")

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
df_sub = df[(df["판매유형별"] != "계")&(df['판매유형별']!='면세점')].copy()
sns.lineplot(data=df_sub, x="기간", y="백만원", hue="판매유형별")

# %%
df_fashion=df[df['상품군별']=='의류 및 패션관련 상품'].copy()
df_fashion.head()
# Out:
#    국가(대륙)별          상품군별   판매유형별        기간     백만원    연도  분기
# 21      미국  의류 및 패션관련 상품       계  2014 1/4  9810.0  2014   1
# 22      미국  의류 및 패션관련 상품     면세점  2014 1/4     NaN  2014   1
# 23      미국  의류 및 패션관련 상품  면세점 이외  2014 1/4     NaN  2014   1
# 66      미국  의류 및 패션관련 상품       계  2014 2/4  7801.0  2014   2
# 67      미국  의류 및 패션관련 상품     면세점  2014 2/4     NaN  2014   2

# %%
plt.figure(figsize=(15,4))
plt.xticks(rotation=30)
sns.lineplot(data=df_fashion,x='기간',y='백만원',hue='국가(대륙)별')

# %%
df_fashion2 = df[(df["상품군별"] == "의류 및 패션관련 상품") & (df["판매유형별"] != "계")].copy()

plt.figure(figsize=(15, 4))
plt.xticks(rotation=30)
sns.lineplot(data=df_fashion2, x="기간", y="백만원", hue="판매유형별", ci=None)

# %%
df_total
# Out:
#      국가(대륙)별          상품군별 판매유형별           기간     백만원    연도  분기
# 3         미국    컴퓨터 및 주변기기     계     2014 1/4  2216.0  2014   1
# 6         미국    가전·전자·통신기기     계     2014 1/4  2875.0  2014   1
# 9         미국         소프트웨어     계     2014 1/4    47.0  2014   1
# 12        미국           서 적     계     2014 1/4   962.0  2014   1
# 15        미국         사무·문구     계     2014 1/4    25.0  2014   1
# ...      ...           ...   ...          ...     ...   ...  ..
# 1065      미국       아동·유아용품     계  2019 4/4 p)  1928.0  2019   4
# 1068      미국         음·식료품     계  2019 4/4 p)   424.0  2019   4
# 1071      미국         농축수산물     계  2019 4/4 p)     2.0  2019   4
# 1074      미국  생활용품 및 자동차용품     계  2019 4/4 p)  3713.0  2019   4
# 1077      미국           기 타     계  2019 4/4 p)  7353.0  2019   4
#
# [336 rows x 7 columns]

# %%
sns.barplot(data=df_total,x='연도',y='백만원')

# %%
plt.figure(figsize=(15,4))
sns.lineplot(data=df_total,x='연도',y='백만원',hue='국가(대륙)별')

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(data=df_total, x="연도", y="백만원", hue="상품군별")
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0,)
